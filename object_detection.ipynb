# %%
# !python Week10Dataset_process.py
# Out:
# class_idx:  13
# number: 182
# all_idx:  range(0, 182)
# val_number:  36
# val_idx:  [98, 107, 10, 66, 130, 124, 103, 77, 122, 91, 149, 55, 129, 35, 72, 168, 24, 158, 64, 136, 154, 37, 79, 25, 18, 84, 120, 143, 164, 90, 111, 80, 52, 141, 173, 113]
# 146
# normMean = [139.46329485 131.12781297 125.90959682]
# normStd = [53.99856498 54.46404513 56.27036994]
# w, h:  [500, 331]
# w, h:  [500, 331]
#  ********* img_0 *********
# torch.Size([1, 3, 448, 448])
# tensor([[[[-136.0000, -136.0000, -136.0000,  ..., -137.0000, -137.0000,
#            -137.0000],
#           [-136.0000, -136.0000, -136.0000,  ..., -137.0000, -137.0000,
#            -137.0000],
#           [-136.0000, -136.0000, -136.0000,  ..., -137.0000, -137.0000,
#            -137.0000],
#           ...,
#           [-136.9420, -136.0000, -135.7098,  ...,   74.0000,   74.0000,
#              74.0000],
#           [-136.9420, -136.0000, -135.7098,  ...,   74.0000,   74.0000,
#              74.0000],
# ...

# %%
# !python train.py
# Out:
# conv1.weight
# yes
# bn1.weight
# yes
# bn1.bias
# yes
# bn1.running_mean
# yes
# bn1.running_var
# yes
# bn1.num_batches_tracked
# yes
# layer1.0.conv1.weight
# yes
# layer1.0.bn1.weight
# yes
# layer1.0.bn1.bias
# yes
# layer1.0.bn1.running_mean
# yes
# layer1.0.bn1.running_var
# yes
# layer1.0.bn1.num_batches_tracked
# yes
# layer1.0.conv2.weight
# yes
# layer1.0.bn2.weight
# yes
# layer1.0.bn2.bias
# yes
# layer1.0.bn2.running_mean
# yes
# layer1.0.bn2.running_var
# yes
# layer1.0.bn2.num_batches_tracked
# yes
# layer1.0.conv3.weight
# yes
# layer1.0.bn3.weight
# yes
# layer1.0.bn3.bias
# yes
# layer1.0.bn3.running_mean
# yes
# layer1.0.bn3.running_var
# yes
# layer1.0.bn3.num_batches_tracked
# yes
# layer1.0.downsample.0.weight
# yes
# layer1.0.downsample.1.weight
# yes
# layer1.0.downsample.1.bias
# yes
# layer1.0.downsample.1.running_mean
# yes
# layer1.0.downsample.1.running_var
# yes
# layer1.0.downsample.1.num_batches_tracked
# yes
# layer1.1.conv1.weight
# yes
# ...

# %%
# !jupyter notebook --NotebookApp.iopub_msg_rate_limit=100000
# Out:
# [I 15:02:34.305 NotebookApp] Writing notebook server cookie secret to /home/stu_17685590730/.local/share/jupyter/runtime/notebook_cookie_secret
# Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-notebook", line 11, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.7/site-packages/jupyter_core/application.py", line 268, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/traitlets/config/application.py", line 663, in launch_instance
#     app.initialize(argv)
#   File "</opt/conda/lib/python3.7/site-packages/decorator.py:decorator-gen-7>", line 2, in initialize
#   File "/opt/conda/lib/python3.7/site-packages/traitlets/config/application.py", line 87, in catch_config_error
#     return method(app, *args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/notebook/notebookapp.py", line 1769, in initialize
#     self.init_webapp()
# ...

# %%
# !ls
# Out:
# Week10Dataset_process.py  main.py		  train.py
# __pycache__		  object_detection.ipynb  week10_dataset
# ground_true.py		  output		  yolo_v1_loss.py
# input			  predict_decoder.py
# kmeans_for_anchors.py	  resnet_yolo_v1.py

# %%
# !jupyter notebook --generate-config
# Out:
# Writing default config to: /home/stu_17685590730/.jupyter/jupyter_notebook_config.py

# %%
# !python train.py
# Out:
# Epoch 151/200: 100%|█| 73/73 [01:22<00:00,  1.14s/it, average_loss=0.28, loss_cl
# get best test loss 0.28050
# Epoch 152/200: 100%|█| 73/73 [01:21<00:00,  1.12s/it, average_loss=0.3, loss_cls
# Epoch 153/200: 100%|█| 73/73 [01:23<00:00,  1.15s/it, average_loss=0.286, loss_c
# Epoch 154/200: 100%|█| 73/73 [01:24<00:00,  1.16s/it, average_loss=0.297, loss_c
# Epoch 155/200: 100%|█| 73/73 [01:22<00:00,  1.13s/it, average_loss=0.41, loss_cl
# Epoch 156/200: 100%|█| 73/73 [01:22<00:00,  1.12s/it, average_loss=0.282, loss_c
# Epoch 157/200: 100%|█| 73/73 [01:22<00:00,  1.13s/it, average_loss=0.291, loss_c
# Epoch 158/200: 100%|█| 73/73 [01:22<00:00,  1.13s/it, average_loss=0.301, loss_c
# Epoch 159/200: 100%|█| 73/73 [01:20<00:00,  1.10s/it, average_loss=0.274, loss_c
# get best test loss 0.27364
# Epoch 160/200: 100%|█| 73/73 [01:21<00:00,  1.11s/it, average_loss=0.284, loss_c
# Epoch 161/200: 100%|█| 73/73 [01:22<00:00,  1.13s/it, average_loss=0.288, loss_c
# ...

# %%
# !python predict_decoder.py
# Out:
# img name=week10_dataset/image/guozhiwei/7.jpg
# predict_decoder.py:265: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(img[None, :, :, :], volatile=True)
# pred.size: torch.Size([1, 14, 14, 24])
# anchor_w: tensor([[0.8750],
#         [4.2812]])
# anchor_h: tensor([[ 5.0000],
#         [11.9688]])
# pred.size:  torch.Size([1, 14, 14, 24])
# pred.size:  torch.Size([14, 14, 24])
# mask[7,7,1]==1
# box.size: torch.Size([4])
# get a box
# tensor([0.3846, 0.0979, 0.6763, 0.9410])
# the box cls=
# tensor(13)
# the box max_prob
# tensor(0.1551)
# the box contain_prob
# tensor([0.8818])
# float((contain_prob*max_prob)[0])
# 0.13675031065940857
# find a box (7 7 1)
# cls_indexs_len=1
# tensor([0])
# [0]
# [0]
# 1
# get i: 0
# index[0] ious=
# tensor([], size=(1, 0))
# []
# [0]
# ############## write file ./input/detection-results/guozhiwei7.txt##############
# img name=week10_dataset/image/guozhiwei/8.jpg
# ...

# %%
# !python main.py
# Out:
# 21.67% = 其他 AP
# 55.56% = 农夫山泉 AP
# 50.00% = 冰露 AP
# 50.00% = 可口可乐 AP
# 12.72% = 天府可乐 AP
# 16.67% = 娃哈哈 AP
# 0.00% = 康师傅 AP
# 25.00% = 怡宝 AP
# 16.67% = 苏打水 AP
# mAP = 27.59%
# Figure(640x480)

# %%
# !python predict_decoder.py
# Out:
# img name=week10_dataset/image/guozhiwei/7.jpg
# predict_decoder.py:266: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(img[None, :, :, :], volatile=True)
# pred.size: torch.Size([1, 14, 14, 24])
# anchor_w: tensor([[0.8750],
#         [4.2812]])
# anchor_h: tensor([[ 5.0000],
#         [11.9688]])
# pred.size:  torch.Size([1, 14, 14, 24])
# pred.size:  torch.Size([14, 14, 24])
# mask[7,7,1]==1
# box.size: torch.Size([4])
# get a box
# tensor([0.3871, 0.1117, 0.6735, 0.9312])
# the box cls=
# tensor(13)
# the box max_prob
# tensor(0.3848)
# the box contain_prob
# tensor([0.8542])
# float((contain_prob*max_prob)[0])
# 0.32867738604545593
# find a box (7 7 1)
# cls_indexs_len=1
# tensor([0])
# [0]
# [0]
# 1
# get i: 0
# index[0] ious=
# tensor([], size=(1, 0))
# []
# [0]
# ############## write file ./input/detection-results/guozhiwei7.txt##############
# img name=week10_dataset/image/guozhiwei/8.jpg
# ...

# %%
# !python main.py
# Out:
# 23.65% = 其他 AP
# 66.67% = 农夫山泉 AP
# 50.00% = 冰露 AP
# 50.00% = 可口可乐 AP
# 12.72% = 天府可乐 AP
# 16.67% = 娃哈哈 AP
# 0.00% = 康师傅 AP
# 25.00% = 怡宝 AP
# 33.33% = 苏打水 AP
# mAP = 30.89%
# Figure(640x480)

# %%
# !python train.py
# Out:
# conv1.weight
# yes
# bn1.weight
# yes
# bn1.bias
# yes
# bn1.running_mean
# yes
# bn1.running_var
# yes
# bn1.num_batches_tracked
# yes
# layer1.0.conv1.weight
# yes
# layer1.0.bn1.weight
# yes
# layer1.0.bn1.bias
# yes
# layer1.0.bn1.running_mean
# yes
# layer1.0.bn1.running_var
# yes
# layer1.0.bn1.num_batches_tracked
# yes
# layer1.0.conv2.weight
# yes
# layer1.0.bn2.weight
# yes
# layer1.0.bn2.bias
# yes
# layer1.0.bn2.running_mean
# yes
# layer1.0.bn2.running_var
# yes
# layer1.0.bn2.num_batches_tracked
# yes
# layer1.0.conv3.weight
# yes
# layer1.0.bn3.weight
# yes
# layer1.0.bn3.bias
# yes
# layer1.0.bn3.running_mean
# yes
# layer1.0.bn3.running_var
# yes
# layer1.0.bn3.num_batches_tracked
# yes
# layer1.0.downsample.0.weight
# yes
# layer1.0.downsample.1.weight
# yes
# layer1.0.downsample.1.bias
# yes
# layer1.0.downsample.1.running_mean
# yes
# layer1.0.downsample.1.running_var
# yes
# layer1.0.downsample.1.num_batches_tracked
# yes
# layer1.1.conv1.weight
# yes
# ...

# %%
# !python predict_decoder.py
# Out:
# img name=week10_dataset/image/guozhiwei/7.jpg
# predict_decoder.py:266: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(img[None, :, :, :], volatile=True)
# pred.size: torch.Size([1, 14, 14, 24])
# anchor_w: tensor([[0.8750],
#         [4.2812]])
# anchor_h: tensor([[ 5.0000],
#         [11.9688]])
# pred.size:  torch.Size([1, 14, 14, 24])
# pred.size:  torch.Size([14, 14, 24])
# mask[7,7,1]==1
# box.size: torch.Size([4])
# get a box
# tensor([0.3240, 0.1072, 0.6953, 0.9039])
# the box cls=
# tensor(7)
# the box max_prob
# tensor(0.0111)
# the box contain_prob
# tensor([0.5067])
# float((contain_prob*max_prob)[0])
# 0.005628562066704035
# contain_prob*max_prob not > 0.02
# tensor([0])
# [0]
# [0]
# 1
# get i: 0
# index[0] ious=
# tensor([], size=(1, 0))
# []
# [0]
# ############## write file ./input/detection-results/guozhiwei7.txt##############
# img name=week10_dataset/image/guozhiwei/8.jpg
# ...

# %%
# !python main.py
# Out:
# 4.17% = 其他 AP
# 83.33% = 农夫山泉 AP
# 50.00% = 冰露 AP
# 50.00% = 可口可乐 AP
# 7.89% = 天府可乐 AP
# 13.89% = 娃哈哈 AP
# 0.00% = 康师傅 AP
# 0.00% = 怡宝 AP
# 0.00% = 苏打水 AP
# mAP = 23.25%
# Figure(640x480)

# %%
# !python train.py
# Out:
# conv1.weight
# yes
# bn1.weight
# yes
# bn1.bias
# yes
# bn1.running_mean
# yes
# bn1.running_var
# yes
# bn1.num_batches_tracked
# yes
# layer1.0.conv1.weight
# yes
# layer1.0.bn1.weight
# yes
# layer1.0.bn1.bias
# yes
# layer1.0.bn1.running_mean
# yes
# layer1.0.bn1.running_var
# yes
# layer1.0.bn1.num_batches_tracked
# yes
# layer1.0.conv2.weight
# yes
# layer1.0.bn2.weight
# yes
# layer1.0.bn2.bias
# yes
# layer1.0.bn2.running_mean
# yes
# layer1.0.bn2.running_var
# yes
# layer1.0.bn2.num_batches_tracked
# yes
# layer1.0.conv3.weight
# yes
# layer1.0.bn3.weight
# yes
# layer1.0.bn3.bias
# yes
# layer1.0.bn3.running_mean
# yes
# layer1.0.bn3.running_var
# yes
# layer1.0.bn3.num_batches_tracked
# yes
# layer1.0.downsample.0.weight
# yes
# layer1.0.downsample.1.weight
# yes
# layer1.0.downsample.1.bias
# yes
# layer1.0.downsample.1.running_mean
# yes
# layer1.0.downsample.1.running_var
# yes
# layer1.0.downsample.1.num_batches_tracked
# yes
# layer1.1.conv1.weight
# yes
# ...

# %%
# !python predict_decoder.py
# !python main.py
# Out:
# img name=week10_dataset/image/guozhiwei/7.jpg
# predict_decoder.py:268: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(img[None, :, :, :], volatile=True)
# pred.size: torch.Size([1, 14, 14, 24])
# anchor_w: [0.875, 5.0]
# anchor_h: [4.28125, 11.96875]
# pred.size:  torch.Size([1, 14, 14, 24])
# pred.size:  torch.Size([14, 14, 24])
# mask[6,7,1]==1
# box.size: torch.Size([4])
# get a box
# tensor([0.2209, 0.1982, 0.8471, 0.7727])
# the box cls=
# tensor(3)
# the box max_prob
# tensor(0.2215)
# the box contain_prob
# tensor([0.6540])
# float((contain_prob*max_prob)[0])
# 0.14489144086837769
# find a box (6 7 1)
# mask[7,7,1]==1
# box.size: torch.Size([4])
# get a box
# tensor([0.1583, 0.3121, 0.9038, 0.7382])
# the box cls=
# tensor(3)
# the box max_prob
# tensor(0.4876)
# the box contain_prob
# tensor([0.7255])
# float((contain_prob*max_prob)[0])
# 0.3537765443325043
# find a box (7 7 1)
# cls_indexs_len=2
# ...

# %%
import numpy as np
ious = [[0.8, 0.7, 1, 6, 4],[0.8, 0.7, 1, 6, 4]]
ious = np.array(ious)
print(ious.shape)
threshold =1
idx = np.where(ious <= threshold)[1]
print( idx)
# Out:
# (2, 5)
# [0 1 2 0 1 2]

# %%
idx = np.max(ious,axis=0)
print(idx)
# Out:
# [0.8 0.7 1.  6.  4. ]

# %%
import torch
a = torch.tensor([[1,5,62,54], [2,6,2,6]])
b = torch.max(a, 0)
print(b)
# Out:
# torch.return_types.max(
# values=tensor([ 2,  6, 62, 54]),
# indices=tensor([1, 1, 0, 0]))

# %%
# !python train.py
# Out:
# conv1.weight
# yes
# bn1.weight
# yes
# bn1.bias
# yes
# bn1.running_mean
# yes
# bn1.running_var
# yes
# bn1.num_batches_tracked
# yes
# layer1.0.conv1.weight
# yes
# layer1.0.bn1.weight
# yes
# layer1.0.bn1.bias
# yes
# layer1.0.bn1.running_mean
# yes
# layer1.0.bn1.running_var
# yes
# layer1.0.bn1.num_batches_tracked
# yes
# layer1.0.conv2.weight
# yes
# layer1.0.bn2.weight
# yes
# layer1.0.bn2.bias
# yes
# layer1.0.bn2.running_mean
# yes
# layer1.0.bn2.running_var
# yes
# layer1.0.bn2.num_batches_tracked
# yes
# layer1.0.conv3.weight
# yes
# layer1.0.bn3.weight
# yes
# layer1.0.bn3.bias
# yes
# layer1.0.bn3.running_mean
# yes
# layer1.0.bn3.running_var
# yes
# layer1.0.bn3.num_batches_tracked
# yes
# layer1.0.downsample.0.weight
# yes
# layer1.0.downsample.1.weight
# yes
# layer1.0.downsample.1.bias
# yes
# layer1.0.downsample.1.running_mean
# yes
# layer1.0.downsample.1.running_var
# yes
# layer1.0.downsample.1.num_batches_tracked
# yes
# layer1.1.conv1.weight
# yes
# ...

# %%
# !python predict_decoder.py
# !python main.py
